# %% [markdown]
# - 웹페이지 주소 (한국영화데이터베이스)
# - k, f를 이용해 한국, 외국 영화 나누기
# - for 반복문을 이용해 숫자를 1씩 증가하며 데이터 수집
# - 간혹 작은 영화라 정보가 충분하지 않은 경우가 있다
# - 포스터 이미지가 없는 경우 넘어간다 continue
# - 이미지를 테이블에 blob이라는 데이터 타입으로 저장해야 한다
# - 테이블의 첫 번째 칼럼으로 id를 추가해 각 영화를 구분짓는다
# - 키워드를 etc 칼럼의 데이터로 insert 해야 할까?

# %% [markdown]
# 출처: 한국영화데이터베이스
# ![image.png](attachment:image.png)
